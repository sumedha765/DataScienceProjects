# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
import pandas as pd
pd.set_option('display.max_columns',100)
import os
import seaborn as sns
sns.set()
import numpy as np
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
plt.rcParams['figure.figsize'] = 8, 5
plt.style.use("fivethirtyeight")
for dirname, _, filenames in os.walk('Predicting_Coupon_Redemption'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
train_df = pd.read_csv('../Data/train.csv')
campaign_data_df = pd.read_csv('../Data/campaign_data.csv')
coupon_item_mapping_df = pd.read_csv('../Data/coupon_item_mapping.csv')
customer_demographics_df = pd.read_csv('../Data/customer_demographics.csv')
customer_transaction_data_df = pd.read_csv('../Data/customer_transaction_data.csv')
item_data_df = pd.read_csv('../Data/item_data.csv')
test_df = pd.read_csv('../Data/test.csv')
sub_df = pd.read_csv('../Data/sample_submission.csv')

# %%
# Feature Engineering in campaign_data.csv data.
campaign_data_df['start_date'] = pd.to_datetime(campaign_data_df['start_date'], format='%d/%m/%y', dayfirst=True)
campaign_data_df['end_date'] = pd.to_datetime(campaign_data_df['end_date'], format='%d/%m/%y', dayfirst=True)
campaign_data_df['diff_d'] = (campaign_data_df['end_date'] - campaign_data_df['start_date']) / np.timedelta64(1,'D')
campaign_data_df.drop(['start_date','end_date'], axis=1, inplace=True)

# %% [markdown]
# No Feature Engineering required for the train.csv data.

# %% [markdown]
# No Feature Engineering required for the item_data.csv data.

# %% [markdown]
# No Feature Engineering required for the coupon_item_mapping.csv data.

# %% [markdown]
# Feature Engineering in customer_demographics.csv data.

# %%
lb = LabelEncoder()
customer_demographics_df['age_range'] = lb.fit_transform(customer_demographics_df['age_range'])
print(customer_demographics_df['age_range'])
# Out:
# 0      5
# 1      3
# 2      1
# 3      1
# 4      3
#       ..
# 755    2
# 756    3
# 757    3
# 758    1
# 759    1
# Name: age_range, Length: 760, dtype: int32

# %%
# customer_transaction_data.csv
customer_transaction_data_df['date'] = pd.to_datetime(customer_transaction_data_df['date'], format='%Y-%m-%d')
customer_transaction_data_df['date_d'] = customer_transaction_data_df['date'].dt.day.astype('category')
customer_transaction_data_df['date_m'] = customer_transaction_data_df['date'].dt.month.astype('category')
customer_transaction_data_df['date_w'] = customer_transaction_data_df['date'].dt.week.astype('category')
customer_transaction_data_df.drop(['date'], axis=1, inplace=True)

# %%
tgroup = customer_transaction_data_df.groupby(['customer_id']).sum().reset_index()

# %%
# Merge Data.
train_campaign_data = pd.merge(train_df,campaign_data_df,on='campaign_id',how="left")
test_campaign_data= pd.merge(test_df,campaign_data_df,on='campaign_id',how="left")

# %%
# Coupon Item Mapping.
coupon_item_mapping_item_data = pd.merge(coupon_item_mapping_df, item_data_df, on='item_id', how="left")
mci_group = pd.DataFrame()
mci_group[['coupon_id','no_of_items']] = coupon_item_mapping_item_data.groupby('coupon_id').count().reset_index()[
    ['coupon_id','item_id']]
mci_group[['brand_type','category']] = coupon_item_mapping_item_data.groupby('coupon_id').max().reset_index()[
    ['brand_type','category']]

# %%
mdtg = pd.merge(tgroup,customer_demographics_df,on='customer_id',how='outer')

# %%
# Merge all.
mergeddata = pd.merge(train_campaign_data, mdtg, on=['customer_id'], how='left')
mergeddata = pd.merge(mergeddata, mci_group, on=['coupon_id'], how='left')

# %%
mergeddata2 = pd.merge(test_campaign_data, mdtg, on=['customer_id'], how='left')
mergeddata2 = pd.merge(mergeddata2, mci_group, on=['coupon_id'], how='left')
id_df = mergeddata2['id']
# mergeddata.drop(['id'],axis=1,inplace=True)
# mergeddata2.drop(['id'],axis=1,inplace=True)

# %%
print(mergeddata.shape)
print(mergeddata2.shape)
# Out:
# (78369, 21)
# (50226, 20)

# %%
print(mergeddata.head(20))
# Out:
#     id  campaign_id  coupon_id  customer_id  redemption_status campaign_type  \
# 0    1           13         27         1053                  0             X
# 1    2           13        116           48                  0             X
# 2    6            9        635          205                  0             Y
# 3    7           13        644         1050                  0             X
# 4    9            8       1017         1489                  0             X
# 5   11           11        795          793                  0             Y
# 6   14            9        444          590                  0             Y
# 7   15           29        538          368                  0             Y
# 8   17           30        857          523                  0             X
# 9   19            2        559          679                  0             Y
# 10  20            9        575          108                  0             Y
# 11  21           13       1028           89                  0             X
# 12  22            9        705          712                  0             Y
# 13  23           13        517         1067                  0             X
# 14  24            5        893          761                  0             Y
# 15  25           13        796          248                  0             X
# 16  26           11        506         1464                  0             Y
# 17  27            5        689          186                  0             Y
# 18  28           13        268         1152                  0             X
# 19  29            8          8          695                  0             X
#
#     diff_d   item_id  quantity  selling_price  other_discount  \
# 0     47.0   8724905    105551       57120.75       -10282.37
# 1     47.0  10711961     12143       90185.10       -10664.18
# 2     32.0  29048047      1351      117461.66       -17261.79
# 3     47.0   7433477       306       23291.42        -3947.37
# 4     48.0  15813165    139063       67797.49       -11534.90
# 5     46.0  52695189    160304      254460.17       -32397.91
# 6     32.0  37323020    595037      180245.30       -23471.15
# 7     53.0  76054051    198382      266723.64       -34784.97
# 8     46.0   5283933       438       30478.17        -4445.01
# 9     32.0  38033324      1715      157174.90       -22744.22
# 10    32.0   8201727       310       45588.10        -5977.07
# 11    47.0  20302521    211034       77204.99       -17395.66
# 12    32.0  21792036     35305       95848.78       -17694.61
# 13    47.0  27022913     43977      112354.85       -11820.46
# 14    34.0  19533804       886       60106.52        -7578.12
# 15    47.0  40497893    113965      103411.69       -23637.76
# 16    46.0  77298862    195693      305838.44       -49992.33
# 17    34.0  41465624      2275      116378.28       -20643.72
# 18    47.0  85671319     14038      282584.56       -32377.40
# 19    48.0  50612487     14056      216734.14       -23722.14
#
#     coupon_discount  age_range marital_status  rented family_size  \
# 0            -89.05        3.0            NaN     0.0           1
# 1          -1237.79        2.0        Married     0.0           2
# 2          -2145.72        3.0        Married     0.0           2
# 3           -178.10        NaN            NaN     NaN         NaN
# 4           -265.01        3.0        Married     0.0           2
# 5           -989.87        3.0            NaN     0.0           2
# 6           -162.07        2.0            NaN     0.0           2
# 7           -103.30        2.0            NaN     0.0           1
# 8           -388.24        NaN            NaN     NaN         NaN
# 9              0.00        2.0         Single     1.0           2
# 10         -3193.32        3.0            NaN     0.0           1
# 11         -1492.43        3.0            NaN     0.0           1
# 12         -1179.03        3.0        Married     0.0           3
# 13          -226.19        3.0            NaN     0.0           1
# 14          -277.48        NaN            NaN     NaN         NaN
# 15         -1128.80        2.0         Single     0.0           1
# 16           -71.24        0.0            NaN     0.0           1
# 17           -35.62        1.0            NaN     0.0           2
# 18          -491.20        3.0            NaN     0.0           3
# 19          -552.09        4.0        Married     0.0           2
#
#    no_of_children  income_bracket  no_of_items   brand_type        category
# 0             NaN             5.0          125  Established         Grocery
# 1             NaN             3.0            3        Local         Grocery
# 2             NaN             7.0           67  Established  Pharmaceutical
# 3             NaN             NaN            4  Established         Grocery
# 4             NaN             3.0           32  Established         Grocery
# 5               1             5.0           13  Established  Pharmaceutical
# 6             NaN             1.0           14  Established         Grocery
# 7             NaN             5.0            9  Established         Grocery
# 8             NaN             NaN           14  Established         Grocery
# 9             NaN             4.0           31  Established   Packaged Meat
# 10            NaN             5.0            3  Established         Grocery
# 11            NaN             3.0            6  Established         Grocery
# 12              1             5.0          147  Established   Miscellaneous
# 13            NaN             5.0            3  Established  Pharmaceutical
# 14            NaN             NaN            3  Established  Pharmaceutical
# 15            NaN             3.0          134  Established         Grocery
# 16            NaN             1.0            6  Established         Grocery
# 17            NaN             4.0           73  Established  Pharmaceutical
# 18              1            10.0           11  Established  Pharmaceutical
# 19            NaN             6.0         3718        Local         Seafood

# %%
print(mergeddata['redemption_status'].value_counts())
print(mergeddata['redemption_status'].value_counts(normalize=True))
# Out:
# 0    77640
# 1      729
# Name: redemption_status, dtype: int64
# 0    0.990698
# 1    0.009302
# Name: redemption_status, dtype: float64

# %%
# Checking Missing values.
print(mergeddata.isnull().sum())
percent_missing = mergeddata.isnull().sum() * 100 / len(mergeddata)
missing_value_df = pd.DataFrame({'column_name': mergeddata.columns,
                                 'percent_missing': percent_missing})
print(missing_value_df)
mergeddata.drop(['no_of_children','age_range','marital_status','rented','family_size','income_bracket'], axis=1, inplace=True)
print(mergeddata.isnull().sum())
# Out:
# id                       0
# campaign_id              0
# coupon_id                0
# customer_id              0
# redemption_status        0
# campaign_type            0
# diff_d                   0
# item_id                  0
# quantity                 0
# selling_price            0
# other_discount           0
# coupon_discount          0
# age_range            34708
# marital_status       52975
# rented               34708
# family_size          34708
# no_of_children       64313
# income_bracket       34708
# no_of_items              0
# brand_type               0
# category                 0
# dtype: int64
#                          column_name  percent_missing
# id                                id         0.000000
# campaign_id              campaign_id         0.000000
# coupon_id                  coupon_id         0.000000
# customer_id              customer_id         0.000000
# redemption_status  redemption_status         0.000000
# campaign_type          campaign_type         0.000000
# diff_d                        diff_d         0.000000
# item_id                      item_id         0.000000
# quantity                    quantity         0.000000
# selling_price          selling_price         0.000000
# other_discount        other_discount         0.000000
# coupon_discount      coupon_discount         0.000000
# age_range                  age_range        44.287920
# marital_status        marital_status        67.596881
# rented                        rented        44.287920
# family_size              family_size        44.287920
# no_of_children        no_of_children        82.064337
# income_bracket        income_bracket        44.287920
# no_of_items              no_of_items         0.000000
# brand_type                brand_type         0.000000
# category                    category         0.000000
# id                   0
# campaign_id          0
# coupon_id            0
# customer_id          0
# redemption_status    0
# campaign_type        0
# diff_d               0
# item_id              0
# quantity             0
# selling_price        0
# other_discount       0
# coupon_discount      0
# no_of_items          0
# brand_type           0
# category             0
# dtype: int64

# %%
# Checking Missing values.
print(mergeddata2.isnull().sum())
percent_missing = mergeddata2.isnull().sum() * 100 / len(mergeddata2)
missing_value_df = pd.DataFrame({'column_name': mergeddata2.columns,
                                 'percent_missing': percent_missing})
print(missing_value_df)
mergeddata2.drop(['no_of_children','age_range','marital_status','rented','family_size','income_bracket'], axis=1, inplace=True)
print(mergeddata2.isnull().sum())
# Out:
# id                     0
# campaign_id            0
# coupon_id              0
# customer_id            0
# campaign_type          0
# diff_d                 0
# item_id                0
# quantity               0
# selling_price          0
# other_discount         0
# coupon_discount        0
# age_range          19287
# marital_status     32144
# rented             19287
# family_size        19287
# no_of_children     40064
# income_bracket     19287
# no_of_items            0
# brand_type             0
# category               0
# dtype: int64
#                      column_name  percent_missing
# id                            id         0.000000
# campaign_id          campaign_id         0.000000
# coupon_id              coupon_id         0.000000
# customer_id          customer_id         0.000000
# campaign_type      campaign_type         0.000000
# diff_d                    diff_d         0.000000
# item_id                  item_id         0.000000
# quantity                quantity         0.000000
# selling_price      selling_price         0.000000
# other_discount    other_discount         0.000000
# coupon_discount  coupon_discount         0.000000
# age_range              age_range        38.400430
# marital_status    marital_status        63.998726
# rented                    rented        38.400430
# family_size          family_size        38.400430
# no_of_children    no_of_children        79.767451
# income_bracket    income_bracket        38.400430
# no_of_items          no_of_items         0.000000
# brand_type            brand_type         0.000000
# category                category         0.000000
# id                 0
# campaign_id        0
# coupon_id          0
# customer_id        0
# campaign_type      0
# diff_d             0
# item_id            0
# quantity           0
# selling_price      0
# other_discount     0
# coupon_discount    0
# no_of_items        0
# brand_type         0
# category           0
# dtype: int64

# %%
# Feature Encoding.
cols = ['campaign_type','brand_type','category']
lb = LabelEncoder()
for i in cols:
    mergeddata[i] = lb.fit_transform(mergeddata[i])

# %%
for i in cols:
    mergeddata2[i] = lb.fit_transform(mergeddata2[i])

# %%
# Data Analysis. 

# Total number of customers who are provided coupons.
print("Total number of customers",mergeddata['customer_id'].nunique())

# Total number of coupons provided to customers.
print("Total number of coupons",mergeddata['coupon_id'].nunique())

# Total number of campaigns ran.
print("Total number of campaigns",mergeddata['campaign_id'].nunique())
# Out:
# Total number of customers 1428
# Total number of coupons 866
# Total number of campaigns 18

# %%
# No of transactions present/happened in each campaign type.
print(mergeddata.groupby(['campaign_type'])['id'].count())
# Out:
# campaign_type
# 0    57684
# 1    20685
# Name: id, dtype: int64

# %%
# What are average values of customers who redeemed the coupons?
mergeddata[mergeddata["redemption_status"] == 1].mean()
# Out:
# id                   6.422233e+04
# campaign_id          1.334979e+01
# coupon_id            6.458203e+02
# customer_id          8.425610e+02
# redemption_status    1.000000e+00
# campaign_type        1.275720e-01
# diff_d               4.556790e+01
# item_id              4.244385e+07
# quantity             2.517612e+05
# selling_price        1.644162e+05
# other_discount      -2.727146e+04
# coupon_discount     -2.406998e+03
# no_of_items          4.287133e+02
# brand_type           1.220850e-01
# category             4.465021e+00
# dtype: float64

# %%
# Averae coupon discounts given to customers who redeemed the coupon. # Main reason for redemption or not.
print(mergeddata[mergeddata["redemption_status"] == 1]["coupon_discount"].mean())
print(mergeddata[mergeddata["redemption_status"] == 0]["coupon_discount"].mean())
# Out:
# -2406.9981344307257
# -654.0097386656362

# %%
# Tells how observations in our data are distributed in the context of redemption status and type of campaign.
print(pd.crosstab(mergeddata["redemption_status"], mergeddata["campaign_type"]))
# Out:
# campaign_type          0      1
# redemption_status
# 0                  57048  20592
# 1                    636     93

# %%
# No of unique coupons used in each campaign.Some Coupons were used in more than one campaign.
grouped_df = mergeddata.groupby("campaign_id")
grouped_df = grouped_df.agg({"coupon_id": "nunique"})
grouped_df = grouped_df.reset_index()
print(grouped_df)
print(grouped_df['coupon_id'].sum())
# Out:
#     campaign_id  coupon_id
# 0             1         11
# 1             2         16
# 2             3         34
# 3             4         12
# 4             5         11
# 5             6          1
# 6             7          8
# 7             8        208
# 8             9         18
# 9            10         14
# 10           11         13
# 11           12         15
# 12           13        207
# 13           26        181
# 14           27         27
# 15           28         28
# 16           29         33
# 17           30        178
# 1015

# %%
# No of unique customers participated in each campaign.Some Customers participated in more than one campaign.
grouped_df = mergeddata.groupby("campaign_id")
grouped_df = grouped_df.agg({"customer_id": "nunique"})
grouped_df = grouped_df.reset_index()
print(grouped_df)
print(grouped_df['customer_id'].sum())
# Out:
#     campaign_id  customer_id
# 0             1           13
# 1             2           48
# 2             3           12
# 3             4           81
# 4             5          166
# 5             6           65
# 6             7          198
# 7             8         1076
# 8             9          176
# 9            10          123
# 10           11          214
# 11           12          170
# 12           13         1077
# 13           26          332
# 14           27           12
# 15           28           17
# 16           29          118
# 17           30          361
# 4259

# %%
print(mergeddata.pivot_table(
    ["no_of_items","coupon_discount"],
    ["redemption_status"],
    aggfunc="mean"))
# Out:
#                    coupon_discount  no_of_items
# redemption_status
# 0                      -654.009739    78.672875
# 1                     -2406.998134   428.713306

# %%
# Which campaign id resulted in more redemption of coupons? 
redeemed = mergeddata[mergeddata["redemption_status"] == 1]
print(redeemed.pivot_table(
    ["redemption_status"],
    ["campaign_id"],
    aggfunc="count"))
# Out:
#              redemption_status
# campaign_id
# 1                            1
# 2                            5
# 3                            2
# 4                            7
# 5                            7
# 6                            1
# 7                            4
# 8                          199
# 9                           23
# 10                           7
# 11                           6
# 12                          12
# 13                         346
# 26                          52
# 27                           1
# 28                           1
# 29                          16
# 30                          39

# %%
X = mergeddata.drop(['redemption_status'],axis=1)
Y = mergeddata['redemption_status']

# %%
# Handling class imbalance.
# Technique - 1.
fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=2020)
i = 1
auc = []

for train_index, test_index in fold.split(X, Y):
    x_train, x_val = X.iloc[train_index], X.iloc[test_index]
    y_train, y_val = Y.iloc[train_index], Y.iloc[test_index]
    scaler = StandardScaler()
    x_train = scaler.fit_transform(x_train)
    x_val = scaler.transform(x_val)
    mergeddata2 = scaler.transform(mergeddata2)
    m = LGBMClassifier(random_state=80) # 93.23
    m.fit(x_train, y_train)
    pred_prob1 = m.predict_proba(x_val)
    auc.append(roc_auc_score(y_val, pred_prob1[:, 1]))
    i = i + 1

print("AUC Score")
print(sum(auc)/10)
# Out:
# AUC Score
# 0.927883427257051

# %%
# Technique-2:SMOTE
# Oversample the dataset.

from imblearn.over_sampling import SMOTE
from collections import Counter
oversample = SMOTE()
X,Y = oversample.fit_resample(X,Y)
counter = Counter(Y)
print(counter)
# Out:
# Counter({0: 77640, 1: 77640})

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 101)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
classifier_o = AdaBoostClassifier(random_state=20)  # 98.11
classifier_o.fit(X_train,y_train)
pred_prob1 = classifier_o.predict_proba(X_test)
print(roc_auc_score(y_test, pred_prob1[:, 1]))
# Out:
# 0.9831384746369518

# %%
classifier_o = GradientBoostingClassifier(random_state=30)  # 98.74
classifier_o.fit(X_train,y_train)
pred_prob1 = classifier_o.predict_proba(X_test)
print(roc_auc_score(y_test, pred_prob1[:, 1]))
# Out:
# 0.9880396426262122

# %%
classifier_o = LGBMClassifier(random_state=10)  # 99.78
classifier_o.fit(X_train,y_train)
pred_prob1 = classifier_o.predict_proba(X_test)
print(roc_auc_score(y_test,pred_prob1[:,1]))
# Out:
# 0.9983027744450108

# %%
# LGBM Hyperparameter Tuning using Grid Search.
from sklearn.model_selection import GridSearchCV
param_grid = {'learning_rate': [0.1,0.5],
                 'max_depth': [4,5,6],
                 'num_leaves': [10,20],
                 'feature_fraction': [0.6,0.8],
                 'subsample': [0.2,0.6],
                 'objective': ['binary'],
              'metric': ['auc'],
              'is_unbalance':[False],
              'boosting':['gbdt'],
              'num_boost_round':[100],
              'early_stopping_rounds':[30]}

# Build and fit the GridSearchCV.
grid = GridSearchCV(estimator=classifier_o, param_grid=param_grid,
                    cv=10,verbose=10)
grid_results = grid.fit(X_train,y_train,eval_set = (X_test,y_test))
# Summarize the results in a readable format.
print("Best: {0}, using {1}".format(grid_results.best_score_, grid_results.best_params_))
# Out:
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [CV 1/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
#
# [81]	valid_0's auc: 0.988752
# [82]	valid_0's auc: 0.988921
# [83]	valid_0's auc: 0.988995
# [84]	valid_0's auc: 0.989075
# [85]	valid_0's auc: 0.989148
# [86]	valid_0's auc: 0.989242
# [87]	valid_0's auc: 0.989432
# [88]	valid_0's auc: 0.989462
# [89]	valid_0's auc: 0.989563
# [90]	valid_0's auc: 0.989611
# [91]	valid_0's auc: 0.98971
# [92]	valid_0's auc: 0.989765
# [93]	valid_0's auc: 0.989965
# [94]	valid_0's auc: 0.990008
# [95]	valid_0's auc: 0.990056
# [96]	valid_0's auc: 0.990227
# [97]	valid_0's auc: 0.990332
# [98]	valid_0's auc: 0.990356
# [99]	valid_0's auc: 0.990385
# [100]	valid_0's auc: 0.990537
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990537
# [CV 1/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.5s
# [CV 2/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.891713
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.952264
# [3]	valid_0's auc: 0.955456
# [4]	valid_0's auc: 0.958895
# [5]	valid_0's auc: 0.960004
# [6]	valid_0's auc: 0.961955
# [7]	valid_0's auc: 0.962622
# [8]	valid_0's auc: 0.962643
# [9]	valid_0's auc: 0.963317
# [10]	valid_0's auc: 0.963652
# [11]	valid_0's auc: 0.964013
# [12]	valid_0's auc: 0.965516
# [13]	valid_0's auc: 0.965243
# [14]	valid_0's auc: 0.96619
# [15]	valid_0's auc: 0.966631
# [16]	valid_0's auc: 0.967597
# [17]	valid_0's auc: 0.968736
# [18]	valid_0's auc: 0.969863
# [19]	valid_0's auc: 0.96972
# [20]	valid_0's auc: 0.969977
# [21]	valid_0's auc: 0.970558
# [22]	valid_0's auc: 0.971196
# [23]	valid_0's auc: 0.971615
# [24]	valid_0's auc: 0.97181
# [25]	valid_0's auc: 0.97218
# [26]	valid_0's auc: 0.972678
# [27]	valid_0's auc: 0.972804
# [28]	valid_0's auc: 0.973133
# [29]	valid_0's auc: 0.97328
# [30]	valid_0's auc: 0.973359
# [31]	valid_0's auc: 0.973613
# [32]	valid_0's auc: 0.974409
# [33]	valid_0's auc: 0.975592
# [34]	valid_0's auc: 0.975882
# [35]	valid_0's auc: 0.976921
# [36]	valid_0's auc: 0.977406
# [37]	valid_0's auc: 0.977783
# [38]	valid_0's auc: 0.978022
# [39]	valid_0's auc: 0.978406
# [40]	valid_0's auc: 0.978638
# [82]	valid_0's auc: 0.988989
# [83]	valid_0's auc: 0.989037
# [84]	valid_0's auc: 0.98908
# [85]	valid_0's auc: 0.989246
# [86]	valid_0's auc: 0.989285
# [87]	valid_0's auc: 0.989414
# [88]	valid_0's auc: 0.989458
# [89]	valid_0's auc: 0.989535
# [90]	valid_0's auc: 0.989622
# [91]	valid_0's auc: 0.989708
# [92]	valid_0's auc: 0.98973
# [93]	valid_0's auc: 0.98984
# [94]	valid_0's auc: 0.98988
# [95]	valid_0's auc: 0.989924
# [96]	valid_0's auc: 0.989955
# [97]	valid_0's auc: 0.990046
# [98]	valid_0's auc: 0.990081
# [99]	valid_0's auc: 0.990166
# [100]	valid_0's auc: 0.990203
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990203
# [CV 3/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.6s
# [CV 4/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.897644
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.95459
# [3]	valid_0's auc: 0.956979
# [4]	valid_0's auc: 0.959626
# [5]	valid_0's auc: 0.960086
# [6]	valid_0's auc: 0.962327
# [7]	valid_0's auc: 0.962443
# [8]	valid_0's auc: 0.962572
# [9]	valid_0's auc: 0.962995
# [10]	valid_0's auc: 0.963768
# [11]	valid_0's auc: 0.964202
# [12]	valid_0's auc: 0.964573
# [13]	valid_0's auc: 0.964511
# [14]	valid_0's auc: 0.966014
# [15]	valid_0's auc: 0.966578
# [16]	valid_0's auc: 0.967801
# [17]	valid_0's auc: 0.968792
# [18]	valid_0's auc: 0.970154
# [19]	valid_0's auc: 0.970391
# [20]	valid_0's auc: 0.970164
# [21]	valid_0's auc: 0.970722
# [22]	valid_0's auc: 0.97138
# [23]	valid_0's auc: 0.971857
# [24]	valid_0's auc: 0.972147
# [25]	valid_0's auc: 0.972682
# [26]	valid_0's auc: 0.973245
# [27]	valid_0's auc: 0.973437
# [28]	valid_0's auc: 0.973668
# [29]	valid_0's auc: 0.973812
# [30]	valid_0's auc: 0.974035
# [31]	valid_0's auc: 0.974528
# [32]	valid_0's auc: 0.975558
# [33]	valid_0's auc: 0.976565
# [34]	valid_0's auc: 0.976503
# [35]	valid_0's auc: 0.977333
# [36]	valid_0's auc: 0.977883
# [37]	valid_0's auc: 0.978278
# [38]	valid_0's auc: 0.978527
# [39]	valid_0's auc: 0.978932
# [40]	valid_0's auc: 0.979137
# [41]	valid_0's auc: 0.979553
# [42]	valid_0's auc: 0.979641
# [84]	valid_0's auc: 0.98931
# [85]	valid_0's auc: 0.98942
# [86]	valid_0's auc: 0.989449
# [87]	valid_0's auc: 0.989554
# [88]	valid_0's auc: 0.989595
# [89]	valid_0's auc: 0.98966
# [90]	valid_0's auc: 0.989686
# [91]	valid_0's auc: 0.989803
# [92]	valid_0's auc: 0.989866
# [93]	valid_0's auc: 0.98998
# [94]	valid_0's auc: 0.99003
# [95]	valid_0's auc: 0.990061
# [96]	valid_0's auc: 0.990236
# [97]	valid_0's auc: 0.990381
# [98]	valid_0's auc: 0.990422
# [99]	valid_0's auc: 0.990504
# [100]	valid_0's auc: 0.990558
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990558
# [CV 5/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.5s
# [CV 6/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.88933
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.953229
# [3]	valid_0's auc: 0.955266
# [4]	valid_0's auc: 0.959071
# [5]	valid_0's auc: 0.960409
# [6]	valid_0's auc: 0.962033
# [7]	valid_0's auc: 0.962164
# [8]	valid_0's auc: 0.96211
# [9]	valid_0's auc: 0.962689
# [10]	valid_0's auc: 0.963171
# [11]	valid_0's auc: 0.963741
# [12]	valid_0's auc: 0.965209
# [13]	valid_0's auc: 0.964935
# [14]	valid_0's auc: 0.965603
# [15]	valid_0's auc: 0.966235
# [16]	valid_0's auc: 0.967588
# [17]	valid_0's auc: 0.968709
# [18]	valid_0's auc: 0.970134
# [19]	valid_0's auc: 0.97026
# [20]	valid_0's auc: 0.970141
# [21]	valid_0's auc: 0.970791
# [22]	valid_0's auc: 0.971419
# [23]	valid_0's auc: 0.971727
# [24]	valid_0's auc: 0.972129
# [25]	valid_0's auc: 0.972724
# [26]	valid_0's auc: 0.973271
# [27]	valid_0's auc: 0.973375
# [28]	valid_0's auc: 0.973675
# [29]	valid_0's auc: 0.973695
# [30]	valid_0's auc: 0.973933
# [31]	valid_0's auc: 0.974281
# [32]	valid_0's auc: 0.97533
# [33]	valid_0's auc: 0.976467
# [34]	valid_0's auc: 0.976713
# [35]	valid_0's auc: 0.977201
# [36]	valid_0's auc: 0.977451
# [37]	valid_0's auc: 0.977659
# [38]	valid_0's auc: 0.977859
# [39]	valid_0's auc: 0.978153
# [40]	valid_0's auc: 0.978355
# [41]	valid_0's auc: 0.978605
# [42]	valid_0's auc: 0.978772
# [43]	valid_0's auc: 0.979241
# [44]	valid_0's auc: 0.979466
# [45]	valid_0's auc: 0.98023
# [46]	valid_0's auc: 0.980573
# [47]	valid_0's auc: 0.981248
# [48]	valid_0's auc: 0.981472
# [49]	valid_0's auc: 0.981789
# [50]	valid_0's auc: 0.982177
# [51]	valid_0's auc: 0.982693
# [52]	valid_0's auc: 0.983038
# [53]	valid_0's auc: 0.983167
# [54]	valid_0's auc: 0.983289
# [55]	valid_0's auc: 0.983378
# [56]	valid_0's auc: 0.983587
# [57]	valid_0's auc: 0.983814
# [58]	valid_0's auc: 0.984026
# [59]	valid_0's auc: 0.984201
# [60]	valid_0's auc: 0.984724
# [61]	valid_0's auc: 0.984809
# [62]	valid_0's auc: 0.985286
# [63]	valid_0's auc: 0.985715
# [64]	valid_0's auc: 0.985833
# [65]	valid_0's auc: 0.986007
# [66]	valid_0's auc: 0.986295
# [67]	valid_0's auc: 0.986403
# [68]	valid_0's auc: 0.986563
# [69]	valid_0's auc: 0.986709
# [70]	valid_0's auc: 0.986805
# [71]	valid_0's auc: 0.98721
# [72]	valid_0's auc: 0.987614
# [73]	valid_0's auc: 0.987677
# [74]	valid_0's auc: 0.988073
# [75]	valid_0's auc: 0.988358
# [76]	valid_0's auc: 0.988496
# [77]	valid_0's auc: 0.988557
# [78]	valid_0's auc: 0.988625
# [79]	valid_0's auc: 0.98875
# [80]	valid_0's auc: 0.988857
# [81]	valid_0's auc: 0.989031
# [82]	valid_0's auc: 0.989229
# [83]	valid_0's auc: 0.98929
# [84]	valid_0's auc: 0.989353
# [85]	valid_0's auc: 0.989446
# [86]	valid_0's auc: 0.989478
# [87]	valid_0's auc: 0.989601
# [88]	valid_0's auc: 0.989648
# [89]	valid_0's auc: 0.9897
# [90]	valid_0's auc: 0.989744
# [91]	valid_0's auc: 0.989828
# [92]	valid_0's auc: 0.989898
# [93]	valid_0's auc: 0.98997
# [94]	valid_0's auc: 0.990009
# [95]	valid_0's auc: 0.990036
# [96]	valid_0's auc: 0.990195
# [97]	valid_0's auc: 0.990276
# [98]	valid_0's auc: 0.99031
# [99]	valid_0's auc: 0.990404
# [100]	valid_0's auc: 0.990423
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990423
# [CV 6/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.6s
# [CV 7/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.897591
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.955585
# [3]	valid_0's auc: 0.957183
# [4]	valid_0's auc: 0.959689
# [5]	valid_0's auc: 0.957971
# [86]	valid_0's auc: 0.989357
# [87]	valid_0's auc: 0.989481
# [88]	valid_0's auc: 0.989537
# [89]	valid_0's auc: 0.98963
# [90]	valid_0's auc: 0.989725
# [91]	valid_0's auc: 0.989751
# [92]	valid_0's auc: 0.989816
# [93]	valid_0's auc: 0.989966
# [94]	valid_0's auc: 0.990008
# [95]	valid_0's auc: 0.990151
# [96]	valid_0's auc: 0.990161
# [97]	valid_0's auc: 0.990287
# [98]	valid_0's auc: 0.990334
# [99]	valid_0's auc: 0.990451
# [100]	valid_0's auc: 0.990514
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990514
# [CV 7/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.6s
# [CV 8/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.897076
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.953629
# [3]	valid_0's auc: 0.957035
# [4]	valid_0's auc: 0.959316
# [5]	valid_0's auc: 0.960029
# [6]	valid_0's auc: 0.962096
# [7]	valid_0's auc: 0.96276
# [8]	valid_0's auc: 0.96263
# [9]	valid_0's auc: 0.962894
# [10]	valid_0's auc: 0.963612
# [11]	valid_0's auc: 0.963982
# [12]	valid_0's auc: 0.964362
# [13]	valid_0's auc: 0.964498
# [14]	valid_0's auc: 0.965695
# [15]	valid_0's auc: 0.966424
# [16]	valid_0's auc: 0.967919
# [17]	valid_0's auc: 0.968898
# [18]	valid_0's auc: 0.970469
# [19]	valid_0's auc: 0.970825
# [20]	valid_0's auc: 0.970994
# [21]	valid_0's auc: 0.971603
# [22]	valid_0's auc: 0.972337
# [23]	valid_0's auc: 0.972682
# [24]	valid_0's auc: 0.972944
# [25]	valid_0's auc: 0.973387
# [26]	valid_0's auc: 0.97397
# [27]	valid_0's auc: 0.974371
# [28]	valid_0's auc: 0.974697
# [29]	valid_0's auc: 0.974786
# [30]	valid_0's auc: 0.974996
# [31]	valid_0's auc: 0.975068
# [32]	valid_0's auc: 0.976013
# [33]	valid_0's auc: 0.976986
# [34]	valid_0's auc: 0.976948
# [35]	valid_0's auc: 0.977714
# [36]	valid_0's auc: 0.978517
# [37]	valid_0's auc: 0.978788
# [38]	valid_0's auc: 0.979004
# [39]	valid_0's auc: 0.979412
# [40]	valid_0's auc: 0.979834
# [41]	valid_0's auc: 0.980071
# [42]	valid_0's auc: 0.980256
# [43]	valid_0's auc: 0.98086
# [44]	valid_0's auc: 0.981049
# [45]	valid_0's auc: 0.98159
# [46]	valid_0's auc: 0.981976
# [47]	valid_0's auc: 0.982333
# [48]	valid_0's auc: 0.982554
# [49]	valid_0's auc: 0.982835
# [50]	valid_0's auc: 0.983142
# [51]	valid_0's auc: 0.983476
# [52]	valid_0's auc: 0.983784
# [53]	valid_0's auc: 0.983906
# [54]	valid_0's auc: 0.984049
# [55]	valid_0's auc: 0.984242
# [56]	valid_0's auc: 0.984431
# [57]	valid_0's auc: 0.984654
# [58]	valid_0's auc: 0.984752
# [59]	valid_0's auc: 0.985032
# [60]	valid_0's auc: 0.985383
# [61]	valid_0's auc: 0.985669
# [62]	valid_0's auc: 0.985935
# [63]	valid_0's auc: 0.98622
# [64]	valid_0's auc: 0.986315
# [65]	valid_0's auc: 0.98635
# [66]	valid_0's auc: 0.9867
# [67]	valid_0's auc: 0.986792
# [68]	valid_0's auc: 0.986834
# [69]	valid_0's auc: 0.987101
# [70]	valid_0's auc: 0.987264
# [71]	valid_0's auc: 0.987667
# [72]	valid_0's auc: 0.987993
# [73]	valid_0's auc: 0.988038
# [74]	valid_0's auc: 0.988244
# [75]	valid_0's auc: 0.988379
# [76]	valid_0's auc: 0.988462
# [77]	valid_0's auc: 0.988577
# [78]	valid_0's auc: 0.988657
# [79]	valid_0's auc: 0.988778
# [80]	valid_0's auc: 0.988854
# [81]	valid_0's auc: 0.988936
# [82]	valid_0's auc: 0.989194
# [83]	valid_0's auc: 0.989267
# [84]	valid_0's auc: 0.989348
# [85]	valid_0's auc: 0.989497
# [86]	valid_0's auc: 0.989528
# [87]	valid_0's auc: 0.989616
# [88]	valid_0's auc: 0.989654
# [89]	valid_0's auc: 0.989762
# [90]	valid_0's auc: 0.989821
# [91]	valid_0's auc: 0.98992
# [92]	valid_0's auc: 0.98996
# [93]	valid_0's auc: 0.990054
# [94]	valid_0's auc: 0.990101
# [95]	valid_0's auc: 0.990132
# [96]	valid_0's auc: 0.990218
# [97]	valid_0's auc: 0.990293
# [98]	valid_0's auc: 0.990435
# [99]	valid_0's auc: 0.990525
# [100]	valid_0's auc: 0.990584
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990584
# [CV 8/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.6s
# [CV 9/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.891863
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.953572
# [3]	valid_0's auc: 0.955495
# [4]	valid_0's auc: 0.958685
# [5]	valid_0's auc: 0.960085
# [6]	valid_0's auc: 0.961479
# [7]	valid_0's auc: 0.961573
# [88]	valid_0's auc: 0.989231
# [89]	valid_0's auc: 0.98938
# [90]	valid_0's auc: 0.989582
# [91]	valid_0's auc: 0.989604
# [92]	valid_0's auc: 0.989694
# [93]	valid_0's auc: 0.989817
# [94]	valid_0's auc: 0.989853
# [95]	valid_0's auc: 0.989904
# [96]	valid_0's auc: 0.990095
# [97]	valid_0's auc: 0.990247
# [98]	valid_0's auc: 0.990323
# [99]	valid_0's auc: 0.990345
# [100]	valid_0's auc: 0.99041
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.99041
# [CV 9/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.7s
# [CV 10/10; 1/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.891758
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.953619
# [3]	valid_0's auc: 0.955678
# [4]	valid_0's auc: 0.958651
# [5]	valid_0's auc: 0.960165
# [6]	valid_0's auc: 0.96155
# [7]	valid_0's auc: 0.961772
# [8]	valid_0's auc: 0.961834
# [9]	valid_0's auc: 0.96218
# [10]	valid_0's auc: 0.96316
# [11]	valid_0's auc: 0.963826
# [12]	valid_0's auc: 0.9643
# [13]	valid_0's auc: 0.963999
# [14]	valid_0's auc: 0.965394
# [15]	valid_0's auc: 0.965916
# [16]	valid_0's auc: 0.967383
# [17]	valid_0's auc: 0.968495
# [18]	valid_0's auc: 0.969765
# [19]	valid_0's auc: 0.970019
# [20]	valid_0's auc: 0.970115
# [21]	valid_0's auc: 0.970517
# [22]	valid_0's auc: 0.971059
# [23]	valid_0's auc: 0.9716
# [24]	valid_0's auc: 0.972591
# [25]	valid_0's auc: 0.973029
# [26]	valid_0's auc: 0.973499
# [27]	valid_0's auc: 0.9739
# [28]	valid_0's auc: 0.97422
# [29]	valid_0's auc: 0.974163
# [30]	valid_0's auc: 0.974369
# [31]	valid_0's auc: 0.974599
# [32]	valid_0's auc: 0.97558
# [33]	valid_0's auc: 0.976559
# [34]	valid_0's auc: 0.976826
# [35]	valid_0's auc: 0.977626
# [36]	valid_0's auc: 0.978099
# [37]	valid_0's auc: 0.978156
# [38]	valid_0's auc: 0.978501
# [39]	valid_0's auc: 0.978803
# [40]	valid_0's auc: 0.979226
# [41]	valid_0's auc: 0.979689
# [42]	valid_0's auc: 0.979793
# [43]	valid_0's auc: 0.980059
# [44]	valid_0's auc: 0.980198
# [45]	valid_0's auc: 0.980803
# [46]	valid_0's auc: 0.98092
# [47]	valid_0's auc: 0.981602
# [48]	valid_0's auc: 0.981832
# [49]	valid_0's auc: 0.982135
# [50]	valid_0's auc: 0.982347
# [51]	valid_0's auc: 0.982733
# [52]	valid_0's auc: 0.983065
# [53]	valid_0's auc: 0.98329
# [54]	valid_0's auc: 0.983415
# [55]	valid_0's auc: 0.98358
# [56]	valid_0's auc: 0.983937
# [57]	valid_0's auc: 0.984065
# [58]	valid_0's auc: 0.984234
# [59]	valid_0's auc: 0.984494
# [60]	valid_0's auc: 0.984948
# [61]	valid_0's auc: 0.985186
# [62]	valid_0's auc: 0.9856
# [63]	valid_0's auc: 0.986011
# [64]	valid_0's auc: 0.986043
# [65]	valid_0's auc: 0.986154
# [66]	valid_0's auc: 0.986501
# [67]	valid_0's auc: 0.98663
# [68]	valid_0's auc: 0.986714
# [69]	valid_0's auc: 0.98699
# [70]	valid_0's auc: 0.987051
# [71]	valid_0's auc: 0.987503
# [72]	valid_0's auc: 0.987837
# [73]	valid_0's auc: 0.987954
# [74]	valid_0's auc: 0.988264
# [75]	valid_0's auc: 0.988585
# [76]	valid_0's auc: 0.98873
# [77]	valid_0's auc: 0.988798
# [78]	valid_0's auc: 0.988857
# [79]	valid_0's auc: 0.988983
# [80]	valid_0's auc: 0.989069
# [81]	valid_0's auc: 0.989222
# [82]	valid_0's auc: 0.989357
# [83]	valid_0's auc: 0.989405
# [84]	valid_0's auc: 0.98951
# [85]	valid_0's auc: 0.989588
# [86]	valid_0's auc: 0.989612
# [87]	valid_0's auc: 0.989711
# [88]	valid_0's auc: 0.98977
# [89]	valid_0's auc: 0.989853
# [90]	valid_0's auc: 0.989894
# [91]	valid_0's auc: 0.990015
# [92]	valid_0's auc: 0.990062
# [93]	valid_0's auc: 0.990257
# [94]	valid_0's auc: 0.990304
# [95]	valid_0's auc: 0.990346
# [96]	valid_0's auc: 0.990516
# [97]	valid_0's auc: 0.990565
# [98]	valid_0's auc: 0.990633
# [99]	valid_0's auc: 0.990697
# [100]	valid_0's auc: 0.990745
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990745
# [CV 10/10; 1/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.2; total time=   0.7s
# [CV 1/10; 2/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.6
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.889302
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.953564
# [3]	valid_0's auc: 0.955474
# [4]	valid_0's auc: 0.959003
# [5]	valid_0's auc: 0.958037
# [6]	valid_0's auc: 0.959707
# [7]	valid_0's auc: 0.959857
# [8]	valid_0's auc: 0.960177
# [9]	valid_0's auc: 0.961141
# [90]	valid_0's auc: 0.989611
# [91]	valid_0's auc: 0.98971
# [92]	valid_0's auc: 0.989765
# [93]	valid_0's auc: 0.989965
# [94]	valid_0's auc: 0.990008
# [95]	valid_0's auc: 0.990056
# [96]	valid_0's auc: 0.990227
# [97]	valid_0's auc: 0.990332
# [98]	valid_0's auc: 0.990356
# [99]	valid_0's auc: 0.990385
# [100]	valid_0's auc: 0.990537
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990537
# [CV 1/10; 2/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.6; total time=   0.7s
# [CV 2/10; 2/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.6
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.891713
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.952264
# [3]	valid_0's auc: 0.955456
# [4]	valid_0's auc: 0.958895
# [5]	valid_0's auc: 0.960004
# [6]	valid_0's auc: 0.961955
# [7]	valid_0's auc: 0.962622
# [8]	valid_0's auc: 0.962643
# [9]	valid_0's auc: 0.963317
# [10]	valid_0's auc: 0.963652
# [11]	valid_0's auc: 0.964013
# [12]	valid_0's auc: 0.965516
# [13]	valid_0's auc: 0.965243
# [14]	valid_0's auc: 0.96619
# [15]	valid_0's auc: 0.966631
# [16]	valid_0's auc: 0.967597
# [17]	valid_0's auc: 0.968736
# [18]	valid_0's auc: 0.969863
# [19]	valid_0's auc: 0.96972
# [20]	valid_0's auc: 0.969977
# [21]	valid_0's auc: 0.970558
# [22]	valid_0's auc: 0.971196
# [23]	valid_0's auc: 0.971615
# [24]	valid_0's auc: 0.97181
# [25]	valid_0's auc: 0.97218
# [26]	valid_0's auc: 0.972678
# [27]	valid_0's auc: 0.972804
# [28]	valid_0's auc: 0.973133
# [29]	valid_0's auc: 0.97328
# [30]	valid_0's auc: 0.973359
# [31]	valid_0's auc: 0.973613
# [32]	valid_0's auc: 0.974409
# [33]	valid_0's auc: 0.975592
# [34]	valid_0's auc: 0.975882
# [35]	valid_0's auc: 0.976921
# [36]	valid_0's auc: 0.977406
# [37]	valid_0's auc: 0.977783
# [38]	valid_0's auc: 0.978022
# [39]	valid_0's auc: 0.978406
# [40]	valid_0's auc: 0.978638
# [41]	valid_0's auc: 0.978907
# [42]	valid_0's auc: 0.979142
# [43]	valid_0's auc: 0.979803
# [44]	valid_0's auc: 0.979978
# [45]	valid_0's auc: 0.980642
# [46]	valid_0's auc: 0.980851
# [47]	valid_0's auc: 0.981517
# [48]	valid_0's auc: 0.981794
# [49]	valid_0's auc: 0.982119
# [50]	valid_0's auc: 0.982361
# [51]	valid_0's auc: 0.982769
# [52]	valid_0's auc: 0.983096
# [53]	valid_0's auc: 0.983237
# [54]	valid_0's auc: 0.983365
# [55]	valid_0's auc: 0.983532
# [56]	valid_0's auc: 0.983717
# [57]	valid_0's auc: 0.983968
# [58]	valid_0's auc: 0.984092
# [59]	valid_0's auc: 0.984325
# [60]	valid_0's auc: 0.98486
# [61]	valid_0's auc: 0.9851
# [62]	valid_0's auc: 0.985439
# [63]	valid_0's auc: 0.985588
# [64]	valid_0's auc: 0.985714
# [65]	valid_0's auc: 0.985734
# [66]	valid_0's auc: 0.986129
# [67]	valid_0's auc: 0.986231
# [68]	valid_0's auc: 0.986392
# [69]	valid_0's auc: 0.986564
# [70]	valid_0's auc: 0.986692
# [71]	valid_0's auc: 0.987119
# [72]	valid_0's auc: 0.987459
# [73]	valid_0's auc: 0.987616
# [74]	valid_0's auc: 0.987916
# [75]	valid_0's auc: 0.988192
# [76]	valid_0's auc: 0.988299
# [77]	valid_0's auc: 0.988467
# [78]	valid_0's auc: 0.98863
# [79]	valid_0's auc: 0.988759
# [80]	valid_0's auc: 0.988825
# [81]	valid_0's auc: 0.988923
# [82]	valid_0's auc: 0.989047
# [83]	valid_0's auc: 0.989184
# [84]	valid_0's auc: 0.989329
# [85]	valid_0's auc: 0.989518
# [86]	valid_0's auc: 0.989553
# [87]	valid_0's auc: 0.989652
# [88]	valid_0's auc: 0.989678
# [89]	valid_0's auc: 0.989767
# [90]	valid_0's auc: 0.989848
# [91]	valid_0's auc: 0.989923
# [92]	valid_0's auc: 0.990008
# [93]	valid_0's auc: 0.990142
# [94]	valid_0's auc: 0.990181
# [95]	valid_0's auc: 0.990196
# [96]	valid_0's auc: 0.990293
# [97]	valid_0's auc: 0.990354
# [98]	valid_0's auc: 0.990396
# [99]	valid_0's auc: 0.99046
# [100]	valid_0's auc: 0.990506
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.990506
# [CV 2/10; 2/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.6; total time=   0.7s
# [CV 3/10; 2/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.6, is_unbalance=False, learning_rate=0.1, max_depth=4, metric=auc, num_boost_round=100, num_leaves=10, objective=binary, subsample=0.6
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# ...
# [100]	valid_0's auc: 0.999204
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.999204
# [CV 7/10; 48/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.8, is_unbalance=False, learning_rate=0.5, max_depth=6, metric=auc, num_boost_round=100, num_leaves=20, objective=binary, subsample=0.6; total time=   1.1s
# [CV 8/10; 48/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.8, is_unbalance=False, learning_rate=0.5, max_depth=6, metric=auc, num_boost_round=100, num_leaves=20, objective=binary, subsample=0.6
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning
# [77]	valid_0's auc: 0.998952
# [78]	valid_0's auc: 0.998391
# [79]	valid_0's auc: 0.977761
# [80]	valid_0's auc: 0.985716
# [81]	valid_0's auc: 0.997691
# [82]	valid_0's auc: 0.998081
# [83]	valid_0's auc: 0.998128
# [84]	valid_0's auc: 0.998132
# [85]	valid_0's auc: 0.99832
# [86]	valid_0's auc: 0.998116
# [87]	valid_0's auc: 0.996025
# [88]	valid_0's auc: 0.997741
# [89]	valid_0's auc: 0.994892
# [90]	valid_0's auc: 0.997267
# [91]	valid_0's auc: 0.997735
# [92]	valid_0's auc: 0.998098
# [93]	valid_0's auc: 0.997871
# [94]	valid_0's auc: 0.998006
# [95]	valid_0's auc: 0.997786
# [96]	valid_0's auc: 0.997838
# [97]	valid_0's auc: 0.998156
# [98]	valid_0's auc: 0.997946
# [99]	valid_0's auc: 0.997886
# [100]	valid_0's auc: 0.99747
# Did not meet early stopping. Best iteration is:
# [77]	valid_0's auc: 0.998952
# [CV 8/10; 48/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.8, is_unbalance=False, learning_rate=0.5, max_depth=6, metric=auc, num_boost_round=100, num_leaves=20, objective=binary, subsample=0.6; total time=   1.1s
# [CV 9/10; 48/48] START boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.8, is_unbalance=False, learning_rate=0.5, max_depth=6, metric=auc, num_boost_round=100, num_leaves=20, objective=binary, subsample=0.6
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.947289
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.965913
# [3]	valid_0's auc: 0.970272
# [4]	valid_0's auc: 0.974539
# [5]	valid_0's auc: 0.978829
# [6]	valid_0's auc: 0.98086
# [7]	valid_0's auc: 0.982787
# [8]	valid_0's auc: 0.986484
# [9]	valid_0's auc: 0.986985
# [10]	valid_0's auc: 0.987935
# [11]	valid_0's auc: 0.989359
# [12]	valid_0's auc: 0.990832
# [13]	valid_0's auc: 0.991473
# [14]	valid_0's auc: 0.992527
# [15]	valid_0's auc: 0.993215
# [16]	valid_0's auc: 0.993463
# [17]	valid_0's auc: 0.993867
# [18]	valid_0's auc: 0.994327
# [19]	valid_0's auc: 0.994644
# [20]	valid_0's auc: 0.994749
# [21]	valid_0's auc: 0.994978
# [22]	valid_0's auc: 0.995285
# [23]	valid_0's auc: 0.995454
# [24]	valid_0's auc: 0.995737
# [25]	valid_0's auc: 0.996037
# [26]	valid_0's auc: 0.996231
# [27]	valid_0's auc: 0.996438
# [28]	valid_0's auc: 0.996645
# [29]	valid_0's auc: 0.996843
# [30]	valid_0's auc: 0.997028
# [31]	valid_0's auc: 0.997155
# [32]	valid_0's auc: 0.997272
# [33]	valid_0's auc: 0.997391
# [34]	valid_0's auc: 0.997526
# [35]	valid_0's auc: 0.997681
# [36]	valid_0's auc: 0.997772
# [79]	valid_0's auc: 0.999194
# [80]	valid_0's auc: 0.999217
# [81]	valid_0's auc: 0.99923
# [82]	valid_0's auc: 0.999245
# [83]	valid_0's auc: 0.999259
# [84]	valid_0's auc: 0.999233
# [85]	valid_0's auc: 0.999248
# [86]	valid_0's auc: 0.999062
# [87]	valid_0's auc: 0.99915
# [88]	valid_0's auc: 0.999154
# [89]	valid_0's auc: 0.999179
# [90]	valid_0's auc: 0.999188
# [91]	valid_0's auc: 0.999195
# [92]	valid_0's auc: 0.999201
# [93]	valid_0's auc: 0.999214
# [94]	valid_0's auc: 0.999217
# [95]	valid_0's auc: 0.999226
# [96]	valid_0's auc: 0.999229
# [97]	valid_0's auc: 0.999258
# [98]	valid_0's auc: 0.99926
# [99]	valid_0's auc: 0.999263
# [100]	valid_0's auc: 0.999267
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's auc: 0.999267
# [CV 10/10; 48/48] END boosting=gbdt, early_stopping_rounds=30, feature_fraction=0.8, is_unbalance=False, learning_rate=0.5, max_depth=6, metric=auc, num_boost_round=100, num_leaves=20, objective=binary, subsample=0.6; total time=   1.5s
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] early_stopping_round is set=30, early_stopping_rounds=30 will be ignored. Current value: early_stopping_round=30
# [LightGBM] [Warning] num_iterations is set=100, num_boost_round=100 will be ignored. Current value: num_iterations=100
# [1]	valid_0's auc: 0.947534
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.963355
# [3]	valid_0's auc: 0.96732
# [4]	valid_0's auc: 0.973316
# [5]	valid_0's auc: 0.977819
# [6]	valid_0's auc: 0.98253
# [7]	valid_0's auc: 0.983895
# [8]	valid_0's auc: 0.986025
# [9]	valid_0's auc: 0.987255
# [10]	valid_0's auc: 0.988318
# [11]	valid_0's auc: 0.990379
# [12]	valid_0's auc: 0.991643
# [13]	valid_0's auc: 0.992157
# [14]	valid_0's auc: 0.992464
# [15]	valid_0's auc: 0.99291
# [16]	valid_0's auc: 0.993155
# [17]	valid_0's auc: 0.993256
# [18]	valid_0's auc: 0.993623
# [19]	valid_0's auc: 0.994361
# [20]	valid_0's auc: 0.994728
# [21]	valid_0's auc: 0.995026
# [22]	valid_0's auc: 0.995161
# [23]	valid_0's auc: 0.9954
# [24]	valid_0's auc: 0.995667
# [25]	valid_0's auc: 0.995894
# [26]	valid_0's auc: 0.996299
# [27]	valid_0's auc: 0.996463
# [28]	valid_0's auc: 0.996623
# [29]	valid_0's auc: 0.996707
# [30]	valid_0's auc: 0.996771
# [31]	valid_0's auc: 0.996918
# [32]	valid_0's auc: 0.997094
# [33]	valid_0's auc: 0.997202
# [34]	valid_0's auc: 0.99734
# [35]	valid_0's auc: 0.997445
# [36]	valid_0's auc: 0.997558
# [37]	valid_0's auc: 0.997635
# [38]	valid_0's auc: 0.997674
# [39]	valid_0's auc: 0.997734
# [40]	valid_0's auc: 0.997782
# [41]	valid_0's auc: 0.997858
# [42]	valid_0's auc: 0.99793
# [43]	valid_0's auc: 0.998032
# [44]	valid_0's auc: 0.998103
# [45]	valid_0's auc: 0.99816
# [46]	valid_0's auc: 0.998203
# [47]	valid_0's auc: 0.998256
# [48]	valid_0's auc: 0.998277
# [49]	valid_0's auc: 0.998366
# [50]	valid_0's auc: 0.998403
# [51]	valid_0's auc: 0.99843
# [52]	valid_0's auc: 0.998474
# [53]	valid_0's auc: 0.998521
# [54]	valid_0's auc: 0.998546
# [55]	valid_0's auc: 0.998568
# [56]	valid_0's auc: 0.998575
# [57]	valid_0's auc: 0.998573
# [58]	valid_0's auc: 0.998594
# [59]	valid_0's auc: 0.998601
# [60]	valid_0's auc: 0.998609
# [61]	valid_0's auc: 0.998648
# [62]	valid_0's auc: 0.99869
# [63]	valid_0's auc: 0.998706
# [64]	valid_0's auc: 0.998722
# [65]	valid_0's auc: 0.998743
# [66]	valid_0's auc: 0.998783
# [67]	valid_0's auc: 0.998272
# [68]	valid_0's auc: 0.998276
# [69]	valid_0's auc: 0.998319
# [70]	valid_0's auc: 0.998738
# [71]	valid_0's auc: 0.998758
# [72]	valid_0's auc: 0.998774
# [73]	valid_0's auc: 0.998788
# [74]	valid_0's auc: 0.998801
# [75]	valid_0's auc: 0.998819
# [76]	valid_0's auc: 0.998824
# [77]	valid_0's auc: 0.998851
# [78]	valid_0's auc: 0.998873
# [79]	valid_0's auc: 0.998895
# [80]	valid_0's auc: 0.998908
# [81]	valid_0's auc: 0.998938
# [82]	valid_0's auc: 0.998954
# [83]	valid_0's auc: 0.99896
# [84]	valid_0's auc: 0.998974
# [85]	valid_0's auc: 0.998989
# [86]	valid_0's auc: 0.999001
# [87]	valid_0's auc: 0.998973
# [88]	valid_0's auc: 0.998993
# [89]	valid_0's auc: 0.999003
# [90]	valid_0's auc: 0.999005
# [91]	valid_0's auc: 0.999019
# [92]	valid_0's auc: 0.999028
# [93]	valid_0's auc: 0.999039
# [94]	valid_0's auc: 0.999041
# [95]	valid_0's auc: 0.999043
# [96]	valid_0's auc: 0.999066
# [97]	valid_0's auc: 0.99908
# [98]	valid_0's auc: 0.999081
# [99]	valid_0's auc: 0.99909
# [100]	valid_0's auc: 0.998909
# Did not meet early stopping. Best iteration is:
# [99]	valid_0's auc: 0.99909
# Best: 0.987739930556352, using {'boosting': 'gbdt', 'early_stopping_rounds': 30, 'feature_fraction': 0.8, 'is_unbalance': False, 'learning_rate': 0.5, 'max_depth': 6, 'metric': 'auc', 'num_boost_round': 100, 'num_leaves': 20, 'objective': 'binary', 'subsample': 0.2}

# %%
classifier_o = LGBMClassifier(random_state=10,boosting='gbdt',feature_fraction=0.8,is_unbalance=False,learning_rate=0.5,max_depth=6,metric='auc',num_boost_round=100,num_leaves=20,objective='binary',subsample=0.2)  # 99.78
classifier_o.fit(X_train,y_train)
pred_prob1 = classifier_o.predict_proba(X_test)
print(roc_auc_score(y_test,pred_prob1[:,1]))  # 99.89
# Out:
# 0.9989088790306114

# %%
pred = classifier_o.predict(mergeddata2)
sub_df['redemption_status'] = pred
sub_df.to_csv('final_predictions.csv', index=False)
